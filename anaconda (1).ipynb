# %%
import azureml.core
from azureml.core import Workspace

ws = Workspace.from_config()
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code ALKVQX5LZ to authenticate.
# Interactive authentication successfully completed.

# %%
# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
from azureml.core import Workspace, Dataset

subscription_id = '353b9ff5-223a-4dc4-853e-825bc329d30c'
resource_group = 'brinjal'
workspace_name = 'camel'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='bca')
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
data = dataset.to_pandas_dataframe()
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
print(data.isna().sum())
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data= data.iloc[:,:12]
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# ...

# %%
data.corr()
# Out:
#                               id  radius_mean  texture_mean  perimeter_mean  \
# id                      1.000000     0.074626      0.099770        0.073159
# radius_mean             0.074626     1.000000      0.323782        0.997855
# texture_mean            0.099770     0.323782      1.000000        0.329533
# perimeter_mean          0.073159     0.997855      0.329533        1.000000
# area_mean               0.096893     0.987357      0.321086        0.986507
# smoothness_mean        -0.012968     0.170581     -0.023389        0.207278
# compactness_mean        0.000096     0.506124      0.236702        0.556936
# concavity_mean          0.050080     0.676764      0.302418        0.716136
# concave points_mean     0.044158     0.822529      0.293464        0.850977
# symmetry_mean          -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean -0.052511    -0.311631     -0.076437       -0.261477
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

crs = data.corr()
sns.heatmap(crs, cmap='coolwarm')

# %%
diagnosis = data.loc[:,'diagnosis']
encoding_logic = lambda val: 'red' if val=='M' else 'blue'
diagnosis_encoded = diagnosis.map(encoding_logic) # logic will be applied to EVERY element of diagnosis
inputs = data.loc[:,['id','radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'] ]

# %%
import pandas as pd
sm = pd.plotting.scatter_matrix(inputs, c= diagnosis_encoded, figsize=(10,10))
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_tools.py:308: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_tools.py:308: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_tools.py:314: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
import os
foldr = 'bca'
os.makedirs(foldr, exist_ok=True)

# %%
import joblib
from azureml.core import Run
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# Next : command line parameters-> hyperparams that we want to set through RUN-> depth = 10

hp_depth = [5, 10, 15]
# Initialize a RUN
run = Run.get_context()

# %%
fn = lambda v: 1 if v=='M' else 0
y = diagnosis.map(fn)
y.tail()
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(inputs, y, test_size=0.2, random_state=42)

# %%
run.log('depth_forest',hp_depth)
# Out:
# Attempted to log scalar metric depth_forest:
# 5

# %%
clf = RandomForestClassifier(n_estimators= hp_depth)
# SGDClassifier(alpha = hp_regularization)
clf.fit(xtrain,ytrain)
predictions = clf.predict(xtest)

# %%
acc = accuracy_score(predictions, ytest)
run.log('acc',acc)
# Out:
# Attempted to log scalar metric acc:
# 0.956140350877193

# %%
from sklearn.ensemble import RandomForestClassifier
hp_depths = [5, 10, 15]
# Initialize a RUN
best_acc = 0.0
best_model = 0
run = Run.get_context()
for depth in hp_depths:
    run.log('depth_forest',depth)
    clf = RandomForestClassifier(n_estimators= hp_depth)
    clf.fit(xtrain,ytrain)
    predictions = clf.predict(xtest)
    acc = accuracy_score(predictions, ytest)
    if acc > best_acc:
        best_acc=acc
        best_model = clf
    run.log('acc',acc)
joblib.dump(value=best_model, filename='bca/dfbca.pkl')
run.complete()
# Out:
# Attempted to log scalar metric depth_forest:
# 5
# Attempted to log scalar metric acc:
# 0.956140350877193
# Attempted to log scalar metric depth_forest:
# 10
# Attempted to log scalar metric acc:
# 0.9035087719298246
# Attempted to log scalar metric depth_forest:
# 15
# Attempted to log scalar metric acc:
# 0.9385964912280702

# %%
import azureml.core
from azureml.core import Workspace

ws = Workspace.from_config()

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
cluster_name = 'kangaroo'
try:
    configs = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS2_V2', max_nodes=2)
    train_cluster = ComputeTarget.create(ws, cluster_name, configs)
except Exception as ex:
    run.log('exception',ex )

# %%
train_cluster.wait_for_completion(show_output=True)
# Out:
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
# register the model:
# after pickle dump
run.register_model(model_path='outputs/model.pkl', model_name='diabetes_model_automl',
                        tags={'Training context':'scikit-learn'},
                        properties={'AUC': best_run_metrics['AUC_weighted'], 'Accuracy': best_run_metrics['accuracy']})
# Before run.complete()
